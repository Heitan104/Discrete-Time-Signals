# %%
# %pip install sounddevice
# %pip install soundfile
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.fft import  fft, ifft, fftshift 
import soundfile as sf

from IPython.display import Audio

# %%
## DOES NOT WORK

audio = "media/Recording.wav" # make sure the audio file is in your working directory
y, fs = sf.read(audio) # read in audio data (y) and sampling frequency (fs)

Audio(y, rate=fs) # play audio. be sure to specify the rate parameter as your sampling frequency

# %%
## WORKS

audio = "media/Recording.wav" # make sure the audio file is in your working directory

Audio(audio) # play audio. be sure to specify the rate parameter as your sampling frequency
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
